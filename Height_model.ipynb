# %% [markdown]
# <a href="https://colab.research.google.com/github/HMR1998/HeightWeightPrediction/blob/main/Height_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib_inline
from matplotlib.ticker import MultipleLocator
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pickle

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/height_weight/model_data')

# %%
X = np.array(df['Weight(Pounds)']).reshape(-1, 1)
y = df['Height(Inches)'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=66)

lr = LinearRegression().fit(X_train, y_train)

# %%
y_pred = lr.predict(X_test)

# %%
print(f'Training Error Percentage{round(lr.score(X_train, y_train)*100,2)}%')
print(f'Testing Error Percentage{round(lr.score(X_test, y_test)*100,2)}%')
# Out:
# Training Error Percentage17.23%
# Testing Error Percentage18.62%

# %%
plt.scatter(X_train, y_train, color='red')
plt.plot(X_test, y_pred)
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('Trained Data')
plt.show()

# %%
pickle.dump(lr, open('pik1','wb'))

# %%
model2 = pickle.load(open('pik1','rb'))

# %%
lr.predict([[121.43653755]])
# Out:
# array([67.62140729])
